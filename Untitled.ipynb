# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'buynsell.settings')

import django
django.setup()

import sys
import requests
from bs4 import BeautifulSoup

from django.core.files import File

from trade.models import Item

from django.contrib.auth import get_user_model
from django.db.models.aggregates import Count
from random import randint

User = get_user_model()

def main(query):
    url = 'https://search.shopping.naver.com/search/all.nhn'
    params = {'query' : query }
    res = requests.get(url, params=params)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    
    ctn = 0
    userlist = User.objects.filter(is_active=True)
    count = User.objects.filter(is_active=True).aggregate(count=Count('id'))['count']
    item_status = ['a','b','c','s']
        
    def trim(s):
        return ' '.join(s.split())

    for item_tag in soup.select('#_search_list ._itemSection'):
        user = userlist[randint(0, count - 1)] # Index of User
        status = item_status[randint(0, 3)]
        name = trim(item_tag.select('a.tit')[0].text) # title
        price = trim(item_tag.select('.price .num')[0].text).replace(',','') # amount
        img_url = item_tag.select('img[data-original]')[0]['data-original']
    
        try:
            detest = item_tag.select('.detail')[0].text
        except:
            detest = ''

        res = requests.get(img_url, stream=True)
        img_name = os.path.basename(img_url.split('?',1)[0])
        
#         item = Item(user=user, title=name, amount=price, desc=detest, category=query, item_status=status)
#         item.photo.save(img_name, File(res.raw))
#         item.save()
        
        ctn += 1
        if ctn > 20: 
            break
        print(name, price, img_name, detest)
        print('')
        print(user, status)
        print('')

# %%
from category.models import Category

cate = Category.objects.all()
for cat in cate:
    main(cat)
# Out:
# [플루크] FLUKE TL224 / 테스트 리드선 / Test Leads Sure Grip 36000 80301684609.jpg
#
# 11 test8 b
#
# JT602A 테스터 팁잭 JT-602A Test Tip Jack 400 9140118275.jpg
#
# 11 test a
#
# 테스트리드- Kelvin Test Lead 70cm, 금도금, pincer 와 바나나 플러그 - KML7528 / 2ZA/ 4 x 0.22 /70 - 독일 슈트징어 2200 13476275467.jpg
#
# 11 test4 b
#
# FMX-004 ESD Test M 정전 테스터 441150 16950402401.jpg
#
# 11 test2 c
#
# 해외경도계 Display Shore A 경도 테스터 대 한 고무 Test Tool D 45000 20003042990.jpg
#
# 11 test9 a
#
# FLUKE TL75 SHARP TEST LEAD 테스트리더 20880 12896450609.jpg
#
# 11 test9 a
#
# 해외연속성 테스트 폰 블랙 Continuity Test Phone Black/1489784 114200 20050579026.jpg
#
# 11 test2 s
#
# 측정/TEST 606-2 디지털 목재수분계 670500 19223921569.jpg
#
# 11 test9 a
#
# [ADVANTEC] pH시험지(pH Test Paper) 24000 11855132791.jpg
#
# 11 test5 s
#
# 염소농도 테스트 페이퍼 CM-240 (Chorine Test Paper) 7790 12824371457.jpg
#
# 11 test7 b
#
# 해외[해외배송] DIY IC TEST WFBGA48-0.5 264300 19300882166.jpg
#
# 11 test6 c
#
# High Voltage Test Probe HV-40 고압프로브 132000 9219210733.jpg
#
# 11 test2 c
#
# 질산염 테스트 키트 질산염 측정키트 nitrate test kit HI 3874 HI3874 76400 11483393467.jpg
#
# 11 admin c
#
# FLUKE TL75 & SHARP Test Leader 테스트리더 18000 9454509592.jpg
#
# 11 test3 a
#
# [JOHNSON] PH 테스트페이퍼 롤형 - PH TEST PAPER 8000 11988485770.jpg
#
# 11 test10 s
#
# 해외소음계 사운드 테스트 마스터 [SOUND TEST MASTER] UMAREX 437100 18757290530.jpg
#
# 11 test8 a
#
# 해외50 개/대 새 P75-B1 Dia 1.02 미리메터 100 그램 교두 Spear 봄 식 Test 프로브 Pogo 핀 대 한 홈 Tool 7090 20021908429.jpg
#
# 11 test3 b
#
# 테스토스테론 - Test X180 Ignite Free Testosteron 81680 ffb0b6d0-45f4-4d83-958f-c52f02bce38d.jpg
#
# 11 test2 b
#
# 해외Sonin 50270 Digital Moisture Test Meter 270 for Wood 26880 19999758964.jpg
#
# 11 test9 a
#
# (JLS) 유리 시험관 (Test Tube) 사이즈별 5개묶음판매 (실험관 유리관 유리봉) 1000 e625aeb1-478a-40e7-a410-7eb647abc87e.jpg
#
# 11 admin s
